# %%
# string = 'Hydrogen'
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import os
from datetime import datetime
# from torchvision import datasets, transforms, utils
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import Dataset
import torchvision.utils as vutils
import json
import PIL
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/pbs.3475073.pbsha.ib.sockeye/matplotlib-2i8q6ehn because the default path (/home/jovyan/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
torch.cuda.is_available()
# Out:
# True

# %%
import sys
sys.path.insert(1, '/scratch/st-mgorges-1/jtoledom/SynthData/util')

from loaders import generateDatasets, inOut#, saveJSON, loadJSON#, MyData
from NNets import SimpleClas, SimpleDisc, SimpleGen
# from tools import accuracy, tools, per_image_error, predVsTarget
from plotter import myPlots

from train import train

# %%
###Start Here
PATH = "/scratch/st-mgorges-1/jtoledom/nobackup/SynData/KagCerCanRisk/"

dir = str(9)
BATCH_SIZE=30
NUM_WORKERS=8
ngpu = 1
lr = 0.0001
device = torch.device("cuda:0" if (torch.cuda.is_available() and ngpu > 0) else "cpu")

# %%
# dict = inOut().newDict(PATH,dir)
dictFilename = os.listdir(os.path.join(PATH, "Dict", dir))[0]
dict = inOut().loadDict(os.path.join(PATH, "Dict", dir, dictFilename))
dict['BatchSize'] = BATCH_SIZE
dict['NumWorkers'] = NUM_WORKERS
dict['ngpu'] = ngpu
dict['lr'] = lr
dict
# Out:
# {'Class': [],
#  'Gen': ['/scratch/st-mgorges-1/jtoledom/nobackup/SynData/KagCerCanRisk/Models/9/Gen-backup.pt'],
#  'Disc': ['/scratch/st-mgorges-1/jtoledom/nobackup/SynData/KagCerCanRisk/Models/9/Disc-backup.pt'],
#  'Path': ['/scratch/st-mgorges-1/jtoledom/nobackup/SynData/KagCerCanRisk/Dict/9/Dict-2022-03-10-18-09.json'],
#  'PathRoot': ['/scratch/st-mgorges-1/jtoledom/nobackup/SynData/KagCerCanRisk/'],
#  'Dir': '9',
#  'BatchSize': 30,
#  'NumWorkers': 8,
#  'ngpu': 1,
#  'lr': 0.0001,
#  'lambda': 1,
#  'Log': '/scratch/st-mgorges-1/jtoledom/nobackup/SynData/KagCerCanRisk/Logs/9/train.log',
#  'LastUpdated': ['2022-03-10-21:14:10'],
#  'Loss': [-0.13598469816721404,
#   -0.3287599808894671,
#   -0.5278428838803217,
#   -0.6642914827053363,
#   -0.7257908422213334,
#   -0.709106452189959,
#   -0.7537396068756397,
#   -0.8229613166589004,
#   -0.8805566682265356,
#   -0.9087586815540607,
#   -0.9243772534223703,
#   -0.9377515820356516,
#   -0.9492523303398719,
#   -0.960195011817492,
#   -0.9650823015433091,
#   -0.9711541785643651,
#   -0.9765385870750134,
#   -0.9818337995272416,
#   -0.9831607937812805,
#   -0.9868041322781489,
#   -0.9863664484941043,
#   -0.9894209343653458,
#   -0.9910801809567672,
#   -0.992564680484625,
#   -0.9930353348071759],
#  'LossGen': [6.542328976667845,
#   6.375664341908235,
#   5.736494221366369,
#   5.454036180789654,
#   5.4895103596723995,
#   4.618825059670669,
#   4.637353679308524,
#   3.9398233202787547,
#   4.087324398641403,
#   3.685883489938883,
#   3.8469866949778337,
#   3.375287984426205,
#   4.389028283265921,
#   3.343004618699734,
#   3.956066438784966,
#   4.664073918874447,
#   3.279166143674117,
#   2.9624896966494045,
#   4.255570549231309,
#   2.733541292639879,
#   3.1902462587906766,
#   2.9603123298058143,
#   3.026594952895091,
#   2.909237254124421,
#   2.951854543044017],
#  'LossDisc': [-0.11510336055205418,
#   -0.23700631123322707,
#   -0.30383053307349867,
#   -0.3699673826877887,
#   -0.4459311572405008,
#   -0.5678707854105876,
#   -0.6536796184686514,
#   -0.7369994223117828,
#   -0.7887290555697221,
#   -0.8318340205229245,
#   -0.8725066414246192,
#   -0.9003972961352422,
#   -0.9197434393259195,
#   -0.9354643959265488,
#   -0.9457225386913006,
#   -0.9552127054104438,
#   -0.9636519505427434,
#   -0.9666633009910583,
#   -0.9738776202385242,
#   -0.9750271531251761,
#   -0.9803598706538861,
#   -0.9831596085658441,
#   -0.9854971858171316,
#   -0.9840432543020982,
#   -0.9877385886815878]}

# %%
#Load dataloaders
test, test_label = generateDatasets(PATH, s=6).outputDatasets("test")
# train, train_label = generateDatasets().outputDatasets("train")
trainloader, testloader = generateDatasets(PATH, batch_size=BATCH_SIZE, num_workers=NUM_WORKERS).getDataLoaders()
# Out:
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/transforms/transforms.py:280: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   warnings.warn(

# %%
error_list_D, error_list_G  = train(dict, s=6, lam=1).trainWGANs(device, 2000,25)
# Out:
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 6.542328976667845, ErrReg: 7.038535512410677
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 6.375664341908235, ErrReg: 6.879968331410335
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 5.736494221366369, ErrReg: 6.223446550277563
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 5.454036180789654, ErrReg: 5.878712383600382
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 5.4895103596723995, ErrReg: 5.836996690585063
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 4.618825059670669, ErrReg: 4.872490992912879
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 4.637353679308524, ErrReg: 4.834347523175753
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 3.9398233202787547, ErrReg: 4.086115163106185
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 4.087324398641403, ErrReg: 4.206351276773673
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 3.685883489938883, ErrReg: 3.7779150857375217
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 3.8469866949778337, ErrReg: 3.9140232663888197
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 3.375287984426205, ErrReg: 3.426512273458334
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 4.389028283265921, ErrReg: 4.431990174146799
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 3.343004618699734, ErrReg: 3.3759664365878472
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 3.956066438784966, ErrReg: 3.9829139847021837
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 4.664073918874447, ErrReg: 4.687072187662125
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 3.279166143674117, ErrReg: 3.297225711437372
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 2.9624896966494045, ErrReg: 2.9787847193387837
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 4.255570549231309, ErrReg: 4.269561549791923
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 2.733541292639879, ErrReg: 2.7444442888865104
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 3.1902462587906766, ErrReg: 3.1991397853081045
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 2.9603123298058143, ErrReg: 2.9680460737301755
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 3.026594952895091, ErrReg: 3.033137151828179
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 2.909237254124421, ErrReg: 2.9146937200656304
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 2.951854543044017, ErrReg: 2.9581822638328257
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 3.272982127391375, ErrReg: 3.277827400427598
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 2.8924578611667338, ErrReg: 2.8965198351786685
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 3.3415606136505422, ErrReg: 3.3452027485920834
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 2.7476882751171408, ErrReg: 2.7503628639074473
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 2.4984612327355604, ErrReg: 2.501283680017178
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 3.408412658251249, ErrReg: 3.4103687222187338
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 7.084807350085332, ErrReg: 7.087017330985803
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 2.5823194888921885, ErrReg: 2.584359932404298
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 2.7744979503063054, ErrReg: 2.7757743780429545
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 2.736108656112964, ErrReg: 2.737407338160735
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 3.3258511469914365, ErrReg: 3.3277460680558133
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 2.9395174934313846, ErrReg: 2.9406937647324343
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 7.083033685500805, ErrReg: 7.084096193313599
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 2.994644057292205, ErrReg: 2.9954220171158132
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 2.9967264991540175, ErrReg: 2.9979213774204254
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 2.837110901108155, ErrReg: 2.8382116980277576
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 3.124548547543012, ErrReg: 3.125144511461258
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ErrG: 3.061961453694564, ErrReg: 3.062618762254715
# Exception ignored in: <function _releaseLock at 0x2aaaab4cb8b0>
# Traceback (most recent call last):
#   File "/arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/logging/__init__.py", line 223, in _releaseLock
#     def _releaseLock():
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#     989         try:
# --> 990             data = self._data_queue.get(timeout=timeout)
#     991             return (True, data)
#
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/multiprocessing/queues.py in get(self, block, timeout)
#     113                     if not self._poll(timeout):
# --> 114                         raise Empty
#     115                 elif not self._poll():
#
# Empty:
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-7-339fb178e41d> in <module>
# ----> 1 error_list_D, error_list_G  = train(dict, s=6, lam=1).trainWGANs(device, 2000,25)
#
# /scratch/st-mgorges-1/jtoledom/SynthData/train.py in trainWGANs(self, device, epochs, snap)
#     173                         errorG = 0.0
#     174                         errorReg = 0.0
# --> 175                         for (i, data) in enumerate(trainloader):
#     176                                 disc.zero_grad()
#     177                                 x = data[0].to(device)
#
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     519             if self._sampler_iter is None:
#     520                 self._reset()
# --> 521             data = self._next_data()
#     522             self._num_yielded += 1
#     523             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1184
#    1185             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1186             idx, data = self._get_data()
#    1187             self._tasks_outstanding -= 1
#    1188             if self._dataset_kind == _DatasetKind.Iterable:
#
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1150         else:
#    1151             while True:
# -> 1152                 success, data = self._try_get_data()
#    1153                 if success:
#    1154                     return data
#
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#    1001             if len(failed_workers) > 0:
#    1002                 pids_str = ', '.join(str(w.pid) for w in failed_workers)
# -> 1003                 raise RuntimeError('DataLoader worker (pid(s) {}) exited unexpectedly'.format(pids_str)) from e
#    1004             if isinstance(e, queue.Empty):
#    1005                 return (False, None)
#
# RuntimeError: DataLoader worker (pid(s) 178579, 178603, 178627, 178651, 178675, 178699) exited unexpectedly

# %%
error_list_D, error_list_G  = train(dict, s=6).continuetrainWGANs(device, 1000,25)
# Out:
# 24
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:48: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "b*-" (-> color='b'). The keyword argument will take precedence.
#   axs[2, 0].plot(base[:-1], cumulative/np.cumsum(values)[-1], 'b*-',  c='blue', lw=3, ms=5)
# /scratch/st-mgorges-1/jtoledom/SynthData/util/plotter.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r*-" (-> color='r'). The keyword argument will take precedence.
#   axs[2, 0].plot(baseFake[:-1], cumulativeFake/np.cumsum(valuesFake)[-1],'r*-',  c='red', lw=3, ms=5)
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torchvision/utils.py:50: UserWarning: range will be deprecated, please use value_range instead.
#   warnings.warn(warning)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-40e0d33fc57a> in <module>
# ----> 1 error_list_D, error_list_G  = train(dict, s=6).continuetrainWGANs(device, 1000,25)
#
# /scratch/st-mgorges-1/jtoledom/SynthData/train.py in continuetrainWGANs(self, device, epochs, snap)
#     342                         errorD = 0.0
#     343                         errorG = 0.0
# --> 344                         for (i, data) in enumerate(trainloader):
#     345                                 disc.zero_grad()
#     346                                 x = data[0].to(device)
#
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     519             if self._sampler_iter is None:
#     520                 self._reset()
# --> 521             data = self._next_data()
#     522             self._num_yielded += 1
#     523             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1184
#    1185             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1186             idx, data = self._get_data()
#    1187             self._tasks_outstanding -= 1
#    1188             if self._dataset_kind == _DatasetKind.Iterable:
#
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1150         else:
#    1151             while True:
# -> 1152                 success, data = self._try_get_data()
#    1153                 if success:
#    1154                     return data
#
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/site-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#     988         #   (bool: whether successfully get data, any: data if successful else None)
#     989         try:
# --> 990             data = self._data_queue.get(timeout=timeout)
#     991             return (True, data)
#     992         except Exception as e:
#
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/multiprocessing/queues.py in get(self, block, timeout)
#     111                 if block:
#     112                     timeout = deadline - time.monotonic()
# --> 113                     if not self._poll(timeout):
#     114                         raise Empty
#     115                 elif not self._poll():
#
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/multiprocessing/connection.py in poll(self, timeout)
#     260         self._check_closed()
#     261         self._check_readable()
# --> 262         return self._poll(timeout)
#     263
#     264     def __enter__(self):
#
# /arc/project/st-mgorges-1/jupyter/Py3TorchEnv-2/lib/python3.9/multiprocessing/connection.py in _poll(self, timeout)
#     428     def _poll(self, timeout):
#     429         r = wait([self], timeout)
# --> 430         return bool(r)
#     431
#     432
#
# KeyboardInterrupt:

# %%
#Load network
# clas = MLP().to(device)

#Loss
# criterion = nn.NLLLoss()
# opt = optim.Adam(clas.parameters(), lr=lr)


#TRAIN CLASS
# error_list, acc, accTrain = train().trainClass(100,25)

#TRAIN GANs
# error_list_D, error_list_G  = train().trainGANs(100,25, ngpu=1)
#
error_list_D, error_list_G  = train(s=6, lam=0.001).trainWGANs(2000,25)
#
# error_list_D, error_list_G  = train().trainWGANs_GP(100,25)
#
# error_list_D, error_list_G  = train().trainWGANs_GPandUnroll(100,25)

error_list_D, error_list_G  = train(s=6).continuetrainWGANs(1000,25)
